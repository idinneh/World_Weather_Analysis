# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
from citipy import citipy
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
     city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
     if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 753

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"]
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": weather_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | umtata
# Processing Record 3 of Set 1 | kadirli
# Processing Record 4 of Set 1 | mataura
# Processing Record 5 of Set 1 | fortuna
# Processing Record 6 of Set 1 | kapaa
# Processing Record 7 of Set 1 | cayenne
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 10 of Set 1 | dali
# Processing Record 11 of Set 1 | vaini
# Processing Record 12 of Set 1 | mehamn
# Processing Record 13 of Set 1 | hilo
# Processing Record 14 of Set 1 | gurkovo
# Processing Record 15 of Set 1 | port blair
# Processing Record 16 of Set 1 | yatou
# Processing Record 17 of Set 1 | trairi
# Processing Record 18 of Set 1 | waipawa
# Processing Record 19 of Set 1 | port alfred
# Processing Record 20 of Set 1 | bredasdorp
# Processing Record 21 of Set 1 | irtyshskiy
# Processing Record 22 of Set 1 | albany
# Processing Record 23 of Set 1 | zarubino
# Processing Record 24 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 25 of Set 1 | busselton
# Processing Record 26 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 27 of Set 1 | yellowknife
# Processing Record 28 of Set 1 | ndele
# Processing Record 29 of Set 1 | new norfolk
# Processing Record 30 of Set 1 | puerto ayora
# Processing Record 31 of Set 1 | narsaq
# Processing Record 32 of Set 1 | sorvag
# City not found. Skipping...
# Processing Record 33 of Set 1 | tuktoyaktuk
# Processing Record 34 of Set 1 | lompoc
# Processing Record 35 of Set 1 | arteaga
# Processing Record 36 of Set 1 | nome
# Processing Record 37 of Set 1 | arman
# Processing Record 38 of Set 1 | lamu
# Processing Record 39 of Set 1 | cabo san lucas
# Processing Record 40 of Set 1 | acapulco
# Processing Record 41 of Set 1 | isangel
# Processing Record 42 of Set 1 | dikson
# Processing Record 43 of Set 1 | qaanaaq
# Processing Record 44 of Set 1 | derzhavinsk
# Processing Record 45 of Set 1 | fare
# Processing Record 46 of Set 1 | meiganga
# Processing Record 47 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 48 of Set 1 | gigmoto
# Processing Record 49 of Set 1 | ouadda
# Processing Record 50 of Set 1 | chaozhou
# Processing Record 1 of Set 2 | riyadh
# Processing Record 2 of Set 2 | nikolskoye
# Processing Record 3 of Set 2 | imperia
# Processing Record 4 of Set 2 | barrow
# Processing Record 5 of Set 2 | pevek
# Processing Record 6 of Set 2 | afmadu
# City not found. Skipping...
# Processing Record 7 of Set 2 | rio grande
# Processing Record 8 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 9 of Set 2 | ilulissat
# Processing Record 10 of Set 2 | listvyanskiy
# Processing Record 11 of Set 2 | hami
# Processing Record 12 of Set 2 | cherskiy
# Processing Record 13 of Set 2 | hamilton
# Processing Record 14 of Set 2 | nhulunbuy
# Processing Record 15 of Set 2 | kutum
# Processing Record 16 of Set 2 | carnarvon
# Processing Record 17 of Set 2 | vao
# Processing Record 18 of Set 2 | ferme-neuve
# Processing Record 19 of Set 2 | kuldur
# Processing Record 20 of Set 2 | punta arenas
# Processing Record 21 of Set 2 | castro
# Processing Record 22 of Set 2 | vila franca do campo
# Processing Record 23 of Set 2 | hithadhoo
# Processing Record 24 of Set 2 | airai
# Processing Record 25 of Set 2 | iqaluit
# Processing Record 26 of Set 2 | hirado
# Processing Record 27 of Set 2 | topolobampo
# Processing Record 28 of Set 2 | ribeira grande
# Processing Record 29 of Set 2 | hobart
# Processing Record 30 of Set 2 | torbay
# Processing Record 31 of Set 2 | lagoa
# Processing Record 32 of Set 2 | jamestown
# Processing Record 33 of Set 2 | taltal
# Processing Record 34 of Set 2 | manta
# Processing Record 35 of Set 2 | viedma
# Processing Record 36 of Set 2 | cape town
# Processing Record 37 of Set 2 | kieta
# Processing Record 38 of Set 2 | paita
# Processing Record 39 of Set 2 | portland
# Processing Record 40 of Set 2 | alice springs
# Processing Record 41 of Set 2 | nyrob
# Processing Record 42 of Set 2 | saryshagan
# City not found. Skipping...
# Processing Record 43 of Set 2 | at-bashi
# Processing Record 44 of Set 2 | saint-philippe
# Processing Record 45 of Set 2 | saskylakh
# Processing Record 46 of Set 2 | muli
# Processing Record 47 of Set 2 | butaritari
# Processing Record 48 of Set 2 | chokurdakh
# Processing Record 49 of Set 2 | pisco
# Processing Record 50 of Set 2 | auki
# Processing Record 1 of Set 3 | marawi
# Processing Record 2 of Set 3 | provideniya
# Processing Record 3 of Set 3 | waddan
# Processing Record 4 of Set 3 | lakes entrance
# Processing Record 5 of Set 3 | geraldton
# Processing Record 6 of Set 3 | belmonte
# Processing Record 7 of Set 3 | kruisfontein
# Processing Record 8 of Set 3 | nove zamky
# Processing Record 9 of Set 3 | new guinlo
# City not found. Skipping...
# Processing Record 10 of Set 3 | pleszew
# Processing Record 11 of Set 3 | hodmezovasarhely
# Processing Record 12 of Set 3 | caravelas
# Processing Record 13 of Set 3 | avarua
# Processing Record 14 of Set 3 | faanui
# Processing Record 15 of Set 3 | bandarbeyla
# Processing Record 16 of Set 3 | celestun
# Processing Record 17 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 18 of Set 3 | bambous virieux
# Processing Record 19 of Set 3 | kulhudhuffushi
# Processing Record 20 of Set 3 | akyab
# Processing Record 21 of Set 3 | banda aceh
# Processing Record 22 of Set 3 | frontera
# Processing Record 23 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 24 of Set 3 | tasbuget
# City not found. Skipping...
# Processing Record 25 of Set 3 | pueblo nuevo
# Processing Record 26 of Set 3 | broome
# Processing Record 27 of Set 3 | dibaya
# City not found. Skipping...
# Processing Record 28 of Set 3 | mackay
# Processing Record 29 of Set 3 | cidreira
# Processing Record 30 of Set 3 | tuatapere
# Processing Record 31 of Set 3 | port hardy
# Processing Record 32 of Set 3 | patacamaya
# Processing Record 33 of Set 3 | nizhniy baskunchak
# Processing Record 34 of Set 3 | hermanus
# Processing Record 35 of Set 3 | sorland
# Processing Record 36 of Set 3 | zhigansk
# Processing Record 37 of Set 3 | kemi
# Processing Record 38 of Set 3 | miramar
# Processing Record 39 of Set 3 | port lincoln
# Processing Record 40 of Set 3 | halalo
# City not found. Skipping...
# Processing Record 41 of Set 3 | tiksi
# Processing Record 42 of Set 3 | georgetown
# Processing Record 43 of Set 3 | la ronge
# Processing Record 44 of Set 3 | kolodeznyy
# Processing Record 45 of Set 3 | balabac
# Processing Record 46 of Set 3 | listvyagi
# Processing Record 47 of Set 3 | fairbanks
# Processing Record 48 of Set 3 | mayo
# Processing Record 49 of Set 3 | gazanjyk
# Processing Record 50 of Set 3 | bluff
# Processing Record 1 of Set 4 | kysyl-syr
# Processing Record 2 of Set 4 | shiraz
# Processing Record 3 of Set 4 | veraval
# Processing Record 4 of Set 4 | guerrero negro
# Processing Record 5 of Set 4 | bermeo
# Processing Record 6 of Set 4 | folldal
# Processing Record 7 of Set 4 | tiznit
# Processing Record 8 of Set 4 | sao filipe
# Processing Record 9 of Set 4 | leshukonskoye
# Processing Record 10 of Set 4 | upernavik
# Processing Record 11 of Set 4 | nyurba
# Processing Record 12 of Set 4 | fairview
# Processing Record 13 of Set 4 | gravdal
# Processing Record 14 of Set 4 | gazojak
# Processing Record 15 of Set 4 | bay roberts
# Processing Record 16 of Set 4 | sedalia
# Processing Record 17 of Set 4 | pangnirtung
# Processing Record 18 of Set 4 | victoria
# Processing Record 19 of Set 4 | portobelo
# Processing Record 20 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 21 of Set 4 | antofagasta
# Processing Record 22 of Set 4 | maniitsoq
# Processing Record 23 of Set 4 | beloha
# Processing Record 24 of Set 4 | jiazi
# Processing Record 25 of Set 4 | ponta do sol
# Processing Record 26 of Set 4 | lagos
# Processing Record 27 of Set 4 | tevriz
# Processing Record 28 of Set 4 | atuona
# Processing Record 29 of Set 4 | newport
# Processing Record 30 of Set 4 | sergeyevka
# Processing Record 31 of Set 4 | mpanda
# Processing Record 32 of Set 4 | the valley
# Processing Record 33 of Set 4 | hunza
# City not found. Skipping...
# Processing Record 34 of Set 4 | tunxi
# City not found. Skipping...
# Processing Record 35 of Set 4 | nouadhibou
# Processing Record 36 of Set 4 | biak
# Processing Record 37 of Set 4 | jacareacanga
# Processing Record 38 of Set 4 | mar del plata
# Processing Record 39 of Set 4 | lorengau
# Processing Record 40 of Set 4 | si sa ket
# Processing Record 41 of Set 4 | sitka
# Processing Record 42 of Set 4 | kjopsvik
# Processing Record 43 of Set 4 | solnechnyy
# Processing Record 44 of Set 4 | olenegorsk
# Processing Record 45 of Set 4 | souillac
# Processing Record 46 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 47 of Set 4 | comodoro rivadavia
# Processing Record 48 of Set 4 | mahajanga
# Processing Record 49 of Set 4 | oranjestad
# Processing Record 50 of Set 4 | platteville
# Processing Record 1 of Set 5 | saint-joseph
# Processing Record 2 of Set 5 | totness
# Processing Record 3 of Set 5 | apatou
# Processing Record 4 of Set 5 | ternate
# Processing Record 5 of Set 5 | xinzhou
# Processing Record 6 of Set 5 | bethel
# Processing Record 7 of Set 5 | san lorenzo
# Processing Record 8 of Set 5 | usinsk
# Processing Record 9 of Set 5 | lockhart
# Processing Record 10 of Set 5 | russell
# Processing Record 11 of Set 5 | vestmannaeyjar
# Processing Record 12 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 13 of Set 5 | kayankulam
# Processing Record 14 of Set 5 | flinders
# Processing Record 15 of Set 5 | college
# Processing Record 16 of Set 5 | arraial do cabo
# Processing Record 17 of Set 5 | kasongo
# Processing Record 18 of Set 5 | log
# Processing Record 19 of Set 5 | montepuez
# Processing Record 20 of Set 5 | saint combs
# City not found. Skipping...
# Processing Record 21 of Set 5 | morondava
# Processing Record 22 of Set 5 | east london
# Processing Record 23 of Set 5 | nuristan
# Processing Record 24 of Set 5 | longyearbyen
# Processing Record 25 of Set 5 | severo-kurilsk
# Processing Record 26 of Set 5 | port elizabeth
# Processing Record 27 of Set 5 | bengkulu
# Processing Record 28 of Set 5 | moroto
# Processing Record 29 of Set 5 | alofi
# Processing Record 30 of Set 5 | grand gaube
# Processing Record 31 of Set 5 | kumeny
# Processing Record 32 of Set 5 | thinadhoo
# Processing Record 33 of Set 5 | ahipara
# Processing Record 34 of Set 5 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 35 of Set 5 | codrington
# Processing Record 36 of Set 5 | saint-augustin
# Processing Record 37 of Set 5 | salinopolis
# Processing Record 38 of Set 5 | achisay
# City not found. Skipping...
# Processing Record 39 of Set 5 | bathsheba
# Processing Record 40 of Set 5 | pandan
# Processing Record 41 of Set 5 | piacabucu
# Processing Record 42 of Set 5 | hihifo
# City not found. Skipping...
# Processing Record 43 of Set 5 | quatre cocos
# Processing Record 44 of Set 5 | san patricio
# Processing Record 45 of Set 5 | tsumeb
# Processing Record 46 of Set 5 | pailon
# Processing Record 47 of Set 5 | olafsvik
# Processing Record 48 of Set 5 | bereda
# Processing Record 49 of Set 5 | cururupu
# Processing Record 50 of Set 5 | mahanoro
# Processing Record 1 of Set 6 | komsomolskiy
# Processing Record 2 of Set 6 | kodiak
# Processing Record 3 of Set 6 | benghazi
# Processing Record 4 of Set 6 | xuddur
# Processing Record 5 of Set 6 | novokizhinginsk
# Processing Record 6 of Set 6 | manakara
# Processing Record 7 of Set 6 | pemangkat
# Processing Record 8 of Set 6 | luderitz
# Processing Record 9 of Set 6 | ardabil
# Processing Record 10 of Set 6 | dicabisagan
# Processing Record 11 of Set 6 | itoman
# Processing Record 12 of Set 6 | senneterre
# Processing Record 13 of Set 6 | daru
# Processing Record 14 of Set 6 | kenai
# Processing Record 15 of Set 6 | los llanos de aridane
# Processing Record 16 of Set 6 | chuy
# Processing Record 17 of Set 6 | melaka
# Processing Record 18 of Set 6 | korla
# Processing Record 19 of Set 6 | porbandar
# Processing Record 20 of Set 6 | rossland
# Processing Record 21 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 22 of Set 6 | meulaboh
# Processing Record 23 of Set 6 | singarayakonda
# Processing Record 24 of Set 6 | saint george
# Processing Record 25 of Set 6 | manati
# Processing Record 26 of Set 6 | gamba
# Processing Record 27 of Set 6 | kismayo
# Processing Record 28 of Set 6 | zyryanka
# Processing Record 29 of Set 6 | barra do garcas
# Processing Record 30 of Set 6 | chapais
# Processing Record 31 of Set 6 | maarianhamina
# Processing Record 32 of Set 6 | san cristobal
# Processing Record 33 of Set 6 | bria
# Processing Record 34 of Set 6 | tautira
# Processing Record 35 of Set 6 | tonj
# Processing Record 36 of Set 6 | gorontalo
# Processing Record 37 of Set 6 | namatanai
# Processing Record 38 of Set 6 | thompson
# Processing Record 39 of Set 6 | las varas
# Processing Record 40 of Set 6 | dekoa
# City not found. Skipping...
# Processing Record 41 of Set 6 | rafaela
# Processing Record 42 of Set 6 | lata
# Processing Record 43 of Set 6 | zhongshan
# Processing Record 44 of Set 6 | ambilobe
# Processing Record 45 of Set 6 | asfi
# Processing Record 46 of Set 6 | sao joao da barra
# Processing Record 47 of Set 6 | saldanha
# Processing Record 48 of Set 6 | mount gambier
# Processing Record 49 of Set 6 | vardo
# Processing Record 50 of Set 6 | bairiki
# Processing Record 1 of Set 7 | klaksvik
# Processing Record 2 of Set 7 | shanghai
# Processing Record 3 of Set 7 | batemans bay
# Processing Record 4 of Set 7 | dunedin
# Processing Record 5 of Set 7 | nanortalik
# Processing Record 6 of Set 7 | artyk
# City not found. Skipping...
# Processing Record 7 of Set 7 | la rioja
# Processing Record 8 of Set 7 | dasoguz
# Processing Record 9 of Set 7 | sault sainte marie
# Processing Record 10 of Set 7 | kaitangata
# Processing Record 11 of Set 7 | candawaga
# City not found. Skipping...
# Processing Record 12 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 13 of Set 7 | puerto escondido
# Processing Record 14 of Set 7 | cornereva
# Processing Record 15 of Set 7 | rockland
# Processing Record 16 of Set 7 | idenao
# Processing Record 17 of Set 7 | ciudad bolivar
# Processing Record 18 of Set 7 | lasa
# Processing Record 19 of Set 7 | kirkland lake
# Processing Record 20 of Set 7 | lazaro cardenas
# Processing Record 21 of Set 7 | touros
# Processing Record 22 of Set 7 | faya
# Processing Record 23 of Set 7 | ancud
# Processing Record 24 of Set 7 | sand springs
# Processing Record 25 of Set 7 | brejo da madre de deus
# Processing Record 26 of Set 7 | liwale
# Processing Record 27 of Set 7 | choma
# Processing Record 28 of Set 7 | nadvoitsy
# Processing Record 29 of Set 7 | dalvik
# Processing Record 30 of Set 7 | sao jose da coroa grande
# Processing Record 31 of Set 7 | brighton
# Processing Record 32 of Set 7 | ipira
# Processing Record 33 of Set 7 | tigil
# Processing Record 34 of Set 7 | havre-saint-pierre
# Processing Record 35 of Set 7 | mehran
# Processing Record 36 of Set 7 | navoloki
# Processing Record 37 of Set 7 | neiafu
# Processing Record 38 of Set 7 | tanabe
# Processing Record 39 of Set 7 | sabha
# Processing Record 40 of Set 7 | burica
# City not found. Skipping...
# Processing Record 41 of Set 7 | port hedland
# Processing Record 42 of Set 7 | akdepe
# Processing Record 43 of Set 7 | kastamonu
# Processing Record 44 of Set 7 | beira
# Processing Record 45 of Set 7 | bac lieu
# Processing Record 46 of Set 7 | vanimo
# Processing Record 47 of Set 7 | haibowan
# City not found. Skipping...
# Processing Record 48 of Set 7 | sohag
# Processing Record 49 of Set 7 | tomatlan
# Processing Record 50 of Set 7 | muyezerskiy
# Processing Record 1 of Set 8 | cap malheureux
# Processing Record 2 of Set 8 | half moon bay
# Processing Record 3 of Set 8 | oxford
# Processing Record 4 of Set 8 | kadykchan
# City not found. Skipping...
# Processing Record 5 of Set 8 | kazachinskoye
# Processing Record 6 of Set 8 | hambantota
# Processing Record 7 of Set 8 | indramayu
# Processing Record 8 of Set 8 | san policarpo
# Processing Record 9 of Set 8 | sigli
# Processing Record 10 of Set 8 | tura
# Processing Record 11 of Set 8 | luchegorsk
# Processing Record 12 of Set 8 | hasaki
# Processing Record 13 of Set 8 | lebu
# Processing Record 14 of Set 8 | byron bay
# Processing Record 15 of Set 8 | sapa
# Processing Record 16 of Set 8 | santa cruz
# Processing Record 17 of Set 8 | abu dhabi
# Processing Record 18 of Set 8 | shubarshi
# Processing Record 19 of Set 8 | tambul
# City not found. Skipping...
# Processing Record 20 of Set 8 | nampula
# Processing Record 21 of Set 8 | semey
# Processing Record 22 of Set 8 | kindu
# Processing Record 23 of Set 8 | hoquiam
# Processing Record 24 of Set 8 | grants
# Processing Record 25 of Set 8 | deputatskiy
# Processing Record 26 of Set 8 | neryungri
# Processing Record 27 of Set 8 | ventspils
# Processing Record 28 of Set 8 | filadelfia
# Processing Record 29 of Set 8 | kichera
# Processing Record 30 of Set 8 | kavieng
# Processing Record 31 of Set 8 | talnakh
# Processing Record 32 of Set 8 | novyy yarychiv
# Processing Record 33 of Set 8 | bijie
# Processing Record 34 of Set 8 | la asuncion
# Processing Record 35 of Set 8 | paranhos
# Processing Record 36 of Set 8 | sakakah
# Processing Record 37 of Set 8 | predivinsk
# Processing Record 38 of Set 8 | balsas
# Processing Record 39 of Set 8 | chimbote
# Processing Record 40 of Set 8 | tupelo
# Processing Record 41 of Set 8 | nara
# Processing Record 42 of Set 8 | mumford
# Processing Record 43 of Set 8 | beringovskiy
# Processing Record 44 of Set 8 | maumere
# Processing Record 45 of Set 8 | ierapetra
# Processing Record 46 of Set 8 | srednekolymsk
# Processing Record 47 of Set 8 | bulgan
# Processing Record 48 of Set 8 | khatanga
# Processing Record 49 of Set 8 | jiangyin
# Processing Record 50 of Set 8 | bur gabo
# City not found. Skipping...
# Processing Record 1 of Set 9 | sistranda
# Processing Record 2 of Set 9 | chagoda
# Processing Record 3 of Set 9 | coihaique
# Processing Record 4 of Set 9 | amapa
# Processing Record 5 of Set 9 | goderich
# Processing Record 6 of Set 9 | leningradskiy
# Processing Record 7 of Set 9 | coahuayana
# Processing Record 8 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 9 of Set 9 | kamenka
# Processing Record 10 of Set 9 | adrar
# Processing Record 11 of Set 9 | namibe
# Processing Record 12 of Set 9 | ushtobe
# Processing Record 13 of Set 9 | fivizzano
# Processing Record 14 of Set 9 | hervey bay
# Processing Record 15 of Set 9 | homer
# Processing Record 16 of Set 9 | weiden
# Processing Record 17 of Set 9 | tigre
# Processing Record 18 of Set 9 | gogrial
# Processing Record 19 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 20 of Set 9 | kupino
# Processing Record 21 of Set 9 | pangody
# Processing Record 22 of Set 9 | labuhan
# Processing Record 23 of Set 9 | kandrian
# Processing Record 24 of Set 9 | weligama
# Processing Record 25 of Set 9 | inirida
# Processing Record 26 of Set 9 | sivaki
# Processing Record 27 of Set 9 | nisia floresta
# Processing Record 28 of Set 9 | coquimbo
# Processing Record 29 of Set 9 | aranos
# Processing Record 30 of Set 9 | sorong
# Processing Record 31 of Set 9 | verkhoyansk
# Processing Record 32 of Set 9 | itarema
# Processing Record 33 of Set 9 | alikalia
# Processing Record 34 of Set 9 | esperance
# Processing Record 35 of Set 9 | satitoa
# City not found. Skipping...
# Processing Record 36 of Set 9 | huilong
# Processing Record 37 of Set 9 | hun
# Processing Record 38 of Set 9 | tongliao
# Processing Record 39 of Set 9 | saltillo
# Processing Record 40 of Set 9 | chara
# Processing Record 41 of Set 9 | dudinka
# Processing Record 42 of Set 9 | haines junction
# Processing Record 43 of Set 9 | horodyshche
# Processing Record 44 of Set 9 | fort walton beach
# Processing Record 45 of Set 9 | mildura
# Processing Record 46 of Set 9 | evensk
# Processing Record 47 of Set 9 | henties bay
# Processing Record 48 of Set 9 | ballina
# Processing Record 49 of Set 9 | north bend
# Processing Record 50 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 1 of Set 10 | ugra
# Processing Record 2 of Set 10 | pochutla
# Processing Record 3 of Set 10 | sassandra
# Processing Record 4 of Set 10 | chase
# Processing Record 5 of Set 10 | bardiyah
# Processing Record 6 of Set 10 | karamea
# City not found. Skipping...
# Processing Record 7 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 8 of Set 10 | kangaatsiaq
# Processing Record 9 of Set 10 | taikang
# Processing Record 10 of Set 10 | laguna
# Processing Record 11 of Set 10 | kegayli
# City not found. Skipping...
# Processing Record 12 of Set 10 | hualmay
# Processing Record 13 of Set 10 | acajutla
# Processing Record 14 of Set 10 | santo antonio do ica
# Processing Record 15 of Set 10 | tabukiniberu
# City not found. Skipping...
# Processing Record 16 of Set 10 | bandundu
# Processing Record 17 of Set 10 | seoul
# Processing Record 18 of Set 10 | garrel
# Processing Record 19 of Set 10 | shache
# Processing Record 20 of Set 10 | yeletskiy
# City not found. Skipping...
# Processing Record 21 of Set 10 | tupa
# Processing Record 22 of Set 10 | ixtapa
# Processing Record 23 of Set 10 | kantunilkin
# Processing Record 24 of Set 10 | babra
# Processing Record 25 of Set 10 | hobyo
# Processing Record 26 of Set 10 | ucluelet
# Processing Record 27 of Set 10 | sur
# Processing Record 28 of Set 10 | namie
# Processing Record 29 of Set 10 | hoa binh
# Processing Record 30 of Set 10 | praia
# Processing Record 31 of Set 10 | vestmanna
# Processing Record 32 of Set 10 | davila
# Processing Record 33 of Set 10 | ruatoria
# City not found. Skipping...
# Processing Record 34 of Set 10 | belaya gora
# Processing Record 35 of Set 10 | kunming
# Processing Record 36 of Set 10 | flagstaff
# Processing Record 37 of Set 10 | brae
# Processing Record 38 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 39 of Set 10 | boyolangu
# Processing Record 40 of Set 10 | bernalillo
# Processing Record 41 of Set 10 | mancio lima
# Processing Record 42 of Set 10 | severodvinsk
# Processing Record 43 of Set 10 | norman wells
# Processing Record 44 of Set 10 | chaa-khol
# City not found. Skipping...
# Processing Record 45 of Set 10 | strehaia
# Processing Record 46 of Set 10 | asau
# Processing Record 47 of Set 10 | sechura
# Processing Record 48 of Set 10 | los gatos
# Processing Record 49 of Set 10 | amderma
# City not found. Skipping...
# Processing Record 50 of Set 10 | vryburg
# Processing Record 1 of Set 11 | fort nelson
# Processing Record 2 of Set 11 | chandbali
# Processing Record 3 of Set 11 | saryozek
# Processing Record 4 of Set 11 | tupik
# Processing Record 5 of Set 11 | rawson
# Processing Record 6 of Set 11 | tasiilaq
# Processing Record 7 of Set 11 | hofn
# Processing Record 8 of Set 11 | kholmogory
# Processing Record 9 of Set 11 | flin flon
# Processing Record 10 of Set 11 | cumpas
# Processing Record 11 of Set 11 | iglesias
# Processing Record 12 of Set 11 | dickinson
# Processing Record 13 of Set 11 | belyy yar
# Processing Record 14 of Set 11 | lokosovo
# Processing Record 15 of Set 11 | okato
# Processing Record 16 of Set 11 | nuqui
# Processing Record 17 of Set 11 | mikhaylovsk
# Processing Record 18 of Set 11 | los alamos
# Processing Record 19 of Set 11 | aksu
# Processing Record 20 of Set 11 | susurluk
# Processing Record 21 of Set 11 | fukue
# Processing Record 22 of Set 11 | moissac
# Processing Record 23 of Set 11 | barra do corda
# Processing Record 24 of Set 11 | mahebourg
# Processing Record 25 of Set 11 | nyagan
# Processing Record 26 of Set 11 | jalalabad
# Processing Record 27 of Set 11 | barranca
# Processing Record 28 of Set 11 | westpunt
# City not found. Skipping...
# Processing Record 29 of Set 11 | tarudant
# City not found. Skipping...
# Processing Record 30 of Set 11 | bilibino
# Processing Record 31 of Set 11 | wabash
# Processing Record 32 of Set 11 | tulun
# Processing Record 33 of Set 11 | bonavista
# Processing Record 34 of Set 11 | krasnoselkup
# Processing Record 35 of Set 11 | kavaratti
# Processing Record 36 of Set 11 | borger
# Processing Record 37 of Set 11 | xacmaz
# Processing Record 38 of Set 11 | boulsa
# Processing Record 39 of Set 11 | vila velha
# Processing Record 40 of Set 11 | duz
# City not found. Skipping...
# Processing Record 41 of Set 11 | amparafaravola
# Processing Record 42 of Set 11 | ikongo
# Processing Record 43 of Set 11 | mmathubudukwane
# Processing Record 44 of Set 11 | iwanai
# Processing Record 45 of Set 11 | zhifang
# Processing Record 46 of Set 11 | shiyan
# Processing Record 47 of Set 11 | alotau
# City not found. Skipping...
# Processing Record 48 of Set 11 | pelym
# Processing Record 49 of Set 11 | puerto palomas
# Processing Record 50 of Set 11 | nabire
# Processing Record 1 of Set 12 | na klang
# Processing Record 2 of Set 12 | mutare
# Processing Record 3 of Set 12 | yablonovo
# Processing Record 4 of Set 12 | sinnamary
# Processing Record 5 of Set 12 | bjornevatn
# Processing Record 6 of Set 12 | cockburn town
# Processing Record 7 of Set 12 | abha
# Processing Record 8 of Set 12 | bahir dar
# Processing Record 9 of Set 12 | moranbah
# Processing Record 10 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 11 of Set 12 | dusetos
# Processing Record 12 of Set 12 | nouakchott
# Processing Record 13 of Set 12 | todos santos
# Processing Record 14 of Set 12 | jorochito
# Processing Record 15 of Set 12 | takhtamygda
# Processing Record 16 of Set 12 | wanning
# Processing Record 17 of Set 12 | kargil
# Processing Record 18 of Set 12 | udachnyy
# Processing Record 19 of Set 12 | itaituba
# Processing Record 20 of Set 12 | berlevag
# Processing Record 21 of Set 12 | basco
# Processing Record 22 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 23 of Set 12 | balkhash
# Processing Record 24 of Set 12 | kosh-agach
# Processing Record 25 of Set 12 | clyde river
# Processing Record 26 of Set 12 | kovur
# Processing Record 27 of Set 12 | aklavik
# Processing Record 28 of Set 12 | marihatag
# Processing Record 29 of Set 12 | tuensang
# Processing Record 30 of Set 12 | kashi
# Processing Record 31 of Set 12 | taburi
# City not found. Skipping...
# Processing Record 32 of Set 12 | velizh
# Processing Record 33 of Set 12 | sungairaya
# Processing Record 34 of Set 12 | mana
# Processing Record 35 of Set 12 | batagay
# Processing Record 36 of Set 12 | luba
# Processing Record 37 of Set 12 | hurghada
# Processing Record 38 of Set 12 | ambodifototra
# City not found. Skipping...
# Processing Record 39 of Set 12 | butembo
# Processing Record 40 of Set 12 | roebourne
# Processing Record 41 of Set 12 | cuamba
# Processing Record 42 of Set 12 | palimbang
# Processing Record 43 of Set 12 | opuwo
# Processing Record 44 of Set 12 | laurel
# Processing Record 45 of Set 12 | aguacatan
# Processing Record 46 of Set 12 | novaya zaimka
# Processing Record 47 of Set 12 | falmouth
# Processing Record 48 of Set 12 | kahului
# Processing Record 49 of Set 12 | katangli
# Processing Record 50 of Set 12 | rawlins
# Processing Record 1 of Set 13 | talaya
# Processing Record 2 of Set 13 | gushikawa
# Processing Record 3 of Set 13 | weatherford
# Processing Record 4 of Set 13 | ostrovnoy
# Processing Record 5 of Set 13 | carutapera
# Processing Record 6 of Set 13 | abyek
# Processing Record 7 of Set 13 | sobolevo
# Processing Record 8 of Set 13 | saran
# Processing Record 9 of Set 13 | taseyevo
# Processing Record 10 of Set 13 | port macquarie
# Processing Record 11 of Set 13 | ola
# Processing Record 12 of Set 13 | paamiut
# Processing Record 13 of Set 13 | jumla
# Processing Record 14 of Set 13 | hinatuan
# Processing Record 15 of Set 13 | talcahuano
# Processing Record 16 of Set 13 | west plains
# Processing Record 17 of Set 13 | juneau
# Processing Record 18 of Set 13 | kaeo
# Processing Record 19 of Set 13 | grand river south east
# City not found. Skipping...
# Processing Record 20 of Set 13 | washington
# Processing Record 21 of Set 13 | naze
# Processing Record 22 of Set 13 | asyut
# Processing Record 23 of Set 13 | skelleftea
# Processing Record 24 of Set 13 | brandon
# Processing Record 25 of Set 13 | ketchikan
# Processing Record 26 of Set 13 | ovsyanka
# Processing Record 27 of Set 13 | boende
# Processing Record 28 of Set 13 | qaqortoq
# Processing Record 29 of Set 13 | birjand
# Processing Record 30 of Set 13 | grindavik
# Processing Record 31 of Set 13 | arcata
# Processing Record 32 of Set 13 | chabahar
# Processing Record 33 of Set 13 | zolotinka
# City not found. Skipping...
# Processing Record 34 of Set 13 | atar
# Processing Record 35 of Set 13 | tondano
# Processing Record 36 of Set 13 | rocha
# Processing Record 37 of Set 13 | poum
# Processing Record 38 of Set 13 | winnemucca
# Processing Record 39 of Set 13 | blackwater
# Processing Record 40 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 41 of Set 13 | marienburg
# Processing Record 42 of Set 13 | turayf
# Processing Record 43 of Set 13 | vilyuysk
# Processing Record 44 of Set 13 | bilimbay
# Processing Record 45 of Set 13 | eureka
# Processing Record 46 of Set 13 | montevideo
# Processing Record 47 of Set 13 | mae tha
# Processing Record 48 of Set 13 | nizhniy ingash
# Processing Record 49 of Set 13 | lima
# Processing Record 50 of Set 13 | svetlyy
# Processing Record 1 of Set 14 | pankrushikha
# Processing Record 2 of Set 14 | maldonado
# Processing Record 3 of Set 14 | china
# Processing Record 4 of Set 14 | matongo
# Processing Record 5 of Set 14 | suntar
# Processing Record 6 of Set 14 | voh
# Processing Record 7 of Set 14 | jaswantnagar
# Processing Record 8 of Set 14 | port-gentil
# Processing Record 9 of Set 14 | nchelenge
# Processing Record 10 of Set 14 | uthal
# Processing Record 11 of Set 14 | ust-kuyga
# Processing Record 12 of Set 14 | buchanan
# Processing Record 13 of Set 14 | sao sebastiao do paraiso
# Processing Record 14 of Set 14 | hilpoltstein
# Processing Record 15 of Set 14 | knysna
# Processing Record 16 of Set 14 | privolzhskiy
# Processing Record 17 of Set 14 | rincon
# Processing Record 18 of Set 14 | maryville
# Processing Record 19 of Set 14 | matagami
# Processing Record 20 of Set 14 | bandar-e lengeh
# Processing Record 21 of Set 14 | te anau
# Processing Record 22 of Set 14 | padang
# Processing Record 23 of Set 14 | bamberg
# Processing Record 24 of Set 14 | matara
# Processing Record 25 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 26 of Set 14 | nador
# Processing Record 27 of Set 14 | sentyabrskiy
# City not found. Skipping...
# Processing Record 28 of Set 14 | englewood
# Processing Record 29 of Set 14 | masuguru
# Processing Record 30 of Set 14 | nadym
# Processing Record 31 of Set 14 | aflu
# City not found. Skipping...
# Processing Record 32 of Set 14 | vysha
# Processing Record 33 of Set 14 | khovu-aksy
# Processing Record 34 of Set 14 | eirunepe
# Processing Record 35 of Set 14 | schoneiche
# Processing Record 36 of Set 14 | jurm
# Processing Record 37 of Set 14 | lufilufi
# Processing Record 38 of Set 14 | les cayes
# Processing Record 39 of Set 14 | khorramshahr
# Processing Record 40 of Set 14 | darhan
# Processing Record 41 of Set 14 | adre
# Processing Record 42 of Set 14 | bilma
# Processing Record 43 of Set 14 | saint andrews
# Processing Record 44 of Set 14 | raudeberg
# Processing Record 45 of Set 14 | nishihara
# Processing Record 46 of Set 14 | zatoka
# Processing Record 47 of Set 14 | iralaya
# Processing Record 48 of Set 14 | jinchang
# Processing Record 49 of Set 14 | kudahuvadhoo
# Processing Record 50 of Set 14 | manacor
# Processing Record 1 of Set 15 | ornskoldsvik
# Processing Record 2 of Set 15 | tawkar
# City not found. Skipping...
# Processing Record 3 of Set 15 | cascais
# Processing Record 4 of Set 15 | kawalu
# Processing Record 5 of Set 15 | phan rang
# City not found. Skipping...
# Processing Record 6 of Set 15 | bardsir
# Processing Record 7 of Set 15 | kusk
# City not found. Skipping...
# Processing Record 8 of Set 15 | bidduang
# City not found. Skipping...
# Processing Record 9 of Set 15 | ulaanbaatar
# Processing Record 10 of Set 15 | ambon
# Processing Record 11 of Set 15 | chadiza
# Processing Record 12 of Set 15 | lushunkou
# City not found. Skipping...
# Processing Record 13 of Set 15 | oshawa
# Processing Record 14 of Set 15 | yelizovo
# Processing Record 15 of Set 15 | lishu
# Processing Record 16 of Set 15 | dalmau
# Processing Record 17 of Set 15 | bacabal
# Processing Record 18 of Set 15 | plettenberg bay
# Processing Record 19 of Set 15 | gizo
# Processing Record 20 of Set 15 | balaipungut
# Processing Record 21 of Set 15 | ruse
# Processing Record 22 of Set 15 | paradwip
# City not found. Skipping...
# Processing Record 23 of Set 15 | havre
# Processing Record 24 of Set 15 | teguldet
# Processing Record 25 of Set 15 | tergnier
# Processing Record 26 of Set 15 | arlit
# Processing Record 27 of Set 15 | villa rica
# Processing Record 28 of Set 15 | burdur
# Processing Record 29 of Set 15 | minot
# Processing Record 30 of Set 15 | mehriz
# Processing Record 31 of Set 15 | xunchang
# Processing Record 32 of Set 15 | saquarema
# Processing Record 33 of Set 15 | lubango
# Processing Record 34 of Set 15 | rangpur
# Processing Record 35 of Set 15 | obo
# Processing Record 36 of Set 15 | cazaje
# City not found. Skipping...
# Processing Record 37 of Set 15 | constitucion
# Processing Record 38 of Set 15 | fairhope
# Processing Record 39 of Set 15 | saint-michel-des-saints
# Processing Record 40 of Set 15 | west bay
# Processing Record 41 of Set 15 | altay
# Processing Record 42 of Set 15 | halifax
# Processing Record 43 of Set 15 | san francisco
# Processing Record 44 of Set 15 | pontianak
# Processing Record 45 of Set 15 | bowen
# Processing Record 46 of Set 15 | ozgon
# City not found. Skipping...
# Processing Record 47 of Set 15 | novopokrovka
# Processing Record 48 of Set 15 | katsuura
# Processing Record 49 of Set 15 | cartagena
# Processing Record 50 of Set 15 | ekhabi
# Processing Record 1 of Set 16 | damietta
# Processing Record 2 of Set 16 | surt
# Processing Record 3 of Set 16 | burnie
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 686

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#       City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Ushuaia -54.8000  -68.3000     38.86        87         100       18.41
# 1   Umtata -31.5889   28.7844     55.96       100         100        2.30
# 2  Kadirli  37.3739   36.0961     68.68        75           0        3.58
# 3  Mataura -46.1927  168.8643     47.48        83          77        8.95
# 4  Fortuna  40.5982 -124.1573     58.35        85          72        4.47
# 5    Kapaa  22.0752 -159.3190     79.12        72         100       10.36
# 6  Cayenne   4.9333  -52.3333     75.24        94          20        1.14
# 7  Rikitea -23.1203 -134.9692     69.58        63          64       20.76
# 8     Dali  25.7000  100.1833     70.68        64          66        5.48
# 9    Vaini -21.2000 -175.2000     76.51        83         100        6.46
#
#   Country Current Description
# 0      AR          light rain
# 1      ZA                mist
# 2      TR           clear sky
# 3      NZ       broken clouds
# 4      US       broken clouds
# 5      US     overcast clouds
# 6      GF          few clouds
# 7      PF       broken clouds
# 8      CN       broken clouds
# 9      TO          light rain

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity","Cloudiness", "Wind Speed", "Current Description"]


# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#       City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Ushuaia      AR -54.8000  -68.3000     38.86        87         100
# 1   Umtata      ZA -31.5889   28.7844     55.96       100         100
# 2  Kadirli      TR  37.3739   36.0961     68.68        75           0
# 3  Mataura      NZ -46.1927  168.8643     47.48        83          77
# 4  Fortuna      US  40.5982 -124.1573     58.35        85          72
# 5    Kapaa      US  22.0752 -159.3190     79.12        72         100
# 6  Cayenne      GF   4.9333  -52.3333     75.24        94          20
# 7  Rikitea      PF -23.1203 -134.9692     69.58        63          64
# 8     Dali      CN  25.7000  100.1833     70.68        64          66
# 9    Vaini      TO -21.2000 -175.2000     76.51        83         100
#
#    Wind Speed Current Description
# 0       18.41          light rain
# 1        2.30                mist
# 2        3.58           clear sky
# 3        8.95       broken clouds
# 4        4.47       broken clouds
# 5       10.36     overcast clouds
# 6        1.14          few clouds
# 7       20.76       broken clouds
# 8        5.48       broken clouds
# 9        6.46          light rain

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file)
